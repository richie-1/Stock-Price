# %% [markdown]
# <a href="https://colab.research.google.com/github/richie-1/Stock-Price/blob/main/StockPrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt

# %%
pip install nsepy
# Out:
# Collecting nsepy
#   Downloading https://files.pythonhosted.org/packages/89/52/2e9f0de0c687ad181f17e0783319d31d66869c410793c5b94dc6cd4b3db2/nsepy-0.8.tar.gz
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from nsepy) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from nsepy) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from nsepy) (1.18.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from nsepy) (1.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nsepy) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from nsepy) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from nsepy) (4.2.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->nsepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->nsepy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->nsepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->nsepy) (2.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->nsepy) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->nsepy) (2018.9)
# Building wheels for collected packages: nsepy
#   Building wheel for nsepy (setup.py) ... done
#   Created wheel for nsepy: filename=nsepy-0.8-cp36-none-any.whl size=36085 sha256=87e726e0326d617cd078f6d82c23ceb3619087ed448f520cacbb6e20340b071d
#   Stored in directory: /root/.cache/pip/wheels/05/2c/72/5324e267426eea65dec0c21a12a48b15887c0cf686c7a8fe11
# Successfully built nsepy
# Installing collected packages: nsepy
# Successfully installed nsepy-0.8

# %% [markdown]
# pip install nsepy

# %% [markdown]
# ## Part 1 : Data Selection

# %%
url1 = 'https://raw.githubusercontent.com/richie-1/Stock-Price/main/tcs.csv?token=AQWFQZ53FBUMEFJZM4SWY6K7TLBVW'

# %%
tcs = pd.read_csv(url1)

# %%
url2 = 'https://raw.githubusercontent.com/richie-1/Stock-Price/main/infy.csv?token=AQWFQZ7GLYVDJQNBW7INZJ27TLCLO'
infy = pd.read_csv(url2)

# %%
url3 = 'https://raw.githubusercontent.com/richie-1/Stock-Price/main/n500.csv?token=AQWFQZ4KN4LICMCDGH2JSJ27TLCIM'

# %%
n500 = pd.read_csv(url3)

# %%
# Daily level data TCS
tcs
# Out:
#            Date Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0    2015-01-01    TCS     EQ  ...    8002               52870       0.2883
# 1    2015-01-02    TCS     EQ  ...   27585              309350       0.6683
# 2    2015-01-05    TCS     EQ  ...   43234              456728       0.5207
# 3    2015-01-06    TCS     EQ  ...   84503              714306       0.5894
# 4    2015-01-07    TCS     EQ  ...  101741              886368       0.6724
# ..          ...    ...    ...  ...     ...                 ...          ...
# 490  2016-12-26    TCS     EQ  ...   29524              213160       0.4751
# 491  2016-12-27    TCS     EQ  ...   42719              358760       0.5542
# 492  2016-12-28    TCS     EQ  ...   65267              420288       0.6225
# 493  2016-12-29    TCS     EQ  ...   64945              575262       0.5860
# 494  2016-12-30    TCS     EQ  ...   44979              456203       0.6491
#
# [495 rows x 15 columns]

# %%
# Daily level data Infy
infy
# Out:
#            Date Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0    2015-01-01   INFY     EQ  ...   14908              258080       0.5154
# 1    2015-01-02   INFY     EQ  ...   54166             1249104       0.7371
# 2    2015-01-05   INFY     EQ  ...   82694             1830962       0.7370
# 3    2015-01-06   INFY     EQ  ...  108209             1772070       0.7332
# 4    2015-01-07   INFY     EQ  ...   62463             1317720       0.7270
# ..          ...    ...    ...  ...     ...                 ...          ...
# 490  2016-12-26   INFY     EQ  ...   47565              958338       0.5964
# 491  2016-12-27   INFY     EQ  ...   57508             1430604       0.5824
# 492  2016-12-28   INFY     EQ  ...   81224             1853359       0.6768
# 493  2016-12-29   INFY     EQ  ...   92963             2303901       0.7384
# 494  2016-12-30   INFY     EQ  ...  100569             2574459       0.7085
#
# [495 rows x 15 columns]

# %%
n500
# Out:
#            Date     Open     High      Low    Close     Volume      Turnover
# 0    2015-01-01  6767.60  6794.25  6755.00  6786.10  440905954  7.133120e+10
# 1    2015-01-02  6792.40  6883.05  6792.40  6866.45  617743719  1.216331e+11
# 2    2015-01-05  6877.35  6913.25  6848.25  6857.45  614330577  1.231650e+11
# 3    2015-01-06  6817.65  6817.65  6646.40  6656.80  716905569  1.563956e+11
# 4    2015-01-07  6653.65  6680.50  6605.40  6644.95  723294637  1.507763e+11
# ..          ...      ...      ...      ...      ...        ...           ...
# 490  2016-12-26  6800.20  6801.80  6720.25  6724.45  499941890  1.182531e+11
# 491  2016-12-27  6730.90  6840.85  6711.65  6832.00  568808578  1.324917e+11
# 492  2016-12-28  6849.45  6902.00  6839.90  6847.40  565570193  1.403077e+11
# 493  2016-12-29  6846.80  6920.90  6839.80  6915.45  864984299  1.800378e+11
# 494  2016-12-30  6931.85  6993.40  6928.85  6982.80  636193679  1.358884e+11
#
# [495 rows x 7 columns]

# %% [markdown]
# ### Rolling window analysis of time series

# %%
# Define rolling average function
def roll_avg(close, window):
    sma = close.rolling(window=window).mean().shift()
    return sma

# %%
window = 1
tcs['SMA'] = roll_avg(tcs['Close'], window)

# %%
tcs
# Out:
#            Date Symbol Series  ...  Deliverable Volume  %Deliverble      SMA
# 0    2015-01-01    TCS     EQ  ...               52870       0.2883      NaN
# 1    2015-01-02    TCS     EQ  ...              309350       0.6683  2545.55
# 2    2015-01-05    TCS     EQ  ...              456728       0.5207  2579.45
# 3    2015-01-06    TCS     EQ  ...              714306       0.5894  2540.25
# 4    2015-01-07    TCS     EQ  ...              886368       0.6724  2446.60
# ..          ...    ...    ...  ...                 ...          ...      ...
# 490  2016-12-26    TCS     EQ  ...              213160       0.4751  2288.10
# 491  2016-12-27    TCS     EQ  ...              358760       0.5542  2293.10
# 492  2016-12-28    TCS     EQ  ...              420288       0.6225  2323.40
# 493  2016-12-29    TCS     EQ  ...              575262       0.5860  2313.40
# 494  2016-12-30    TCS     EQ  ...              456203       0.6491  2351.70
#
# [495 rows x 16 columns]

# %%
# 4,16,28,40,52
# Convert week to days
window= []
week = [4,16,28,40, 52]

# %%
for i in range(5):
    day = week[i]*7
    window.append(day)

# %%
window
# Out:
# [28, 112, 196, 280, 364]

# %%
for i in range(5):
    tcs[i+16] = roll_avg(tcs['Close'], window[i])

# %%
tcs
# Out:
#            Date Symbol Series  ...           18           19           20
# 0    2015-01-01    TCS     EQ  ...          NaN          NaN          NaN
# 1    2015-01-02    TCS     EQ  ...          NaN          NaN          NaN
# 2    2015-01-05    TCS     EQ  ...          NaN          NaN          NaN
# 3    2015-01-06    TCS     EQ  ...          NaN          NaN          NaN
# 4    2015-01-07    TCS     EQ  ...          NaN          NaN          NaN
# ..          ...    ...    ...  ...          ...          ...          ...
# 490  2016-12-26    TCS     EQ  ...  2446.231378  2418.161964  2452.208104
# 491  2016-12-27    TCS     EQ  ...  2445.904082  2417.485000  2451.273489
# 492  2016-12-28    TCS     EQ  ...  2445.777041  2416.833750  2450.468956
# 493  2016-12-29    TCS     EQ  ...  2445.512500  2416.269643  2449.695055
# 494  2016-12-30    TCS     EQ  ...  2445.495663  2415.889464  2449.225824
#
# [495 rows x 21 columns]

# %%
tcs.rename(columns= {16:'SMA4',
                     17:'SMA16',
                     18:'SMA28',
                     19:'SMA40',
                     20:'SMA52'}, inplace=True)
tcs.drop(['SMA'], axis=1)
# Out:
#            Date Symbol Series  ...        SMA28        SMA40        SMA52
# 0    2015-01-01    TCS     EQ  ...          NaN          NaN          NaN
# 1    2015-01-02    TCS     EQ  ...          NaN          NaN          NaN
# 2    2015-01-05    TCS     EQ  ...          NaN          NaN          NaN
# 3    2015-01-06    TCS     EQ  ...          NaN          NaN          NaN
# 4    2015-01-07    TCS     EQ  ...          NaN          NaN          NaN
# ..          ...    ...    ...  ...          ...          ...          ...
# 490  2016-12-26    TCS     EQ  ...  2446.231378  2418.161964  2452.208104
# 491  2016-12-27    TCS     EQ  ...  2445.904082  2417.485000  2451.273489
# 492  2016-12-28    TCS     EQ  ...  2445.777041  2416.833750  2450.468956
# 493  2016-12-29    TCS     EQ  ...  2445.512500  2416.269643  2449.695055
# 494  2016-12-30    TCS     EQ  ...  2445.495663  2415.889464  2449.225824
#
# [495 rows x 20 columns]

# %%
for i in range(5):
    infy[i+16] = roll_avg(infy['Close'], window[i])

# %%
infy.rename(columns= {16:'SMA4',
                     17:'SMA16',
                     18:'SMA28',
                     19:'SMA40',
                     20:'SMA52'}, inplace=True)

# %%
infy
# Out:
#            Date Symbol Series  ...        SMA28        SMA40        SMA52
# 0    2015-01-01   INFY     EQ  ...          NaN          NaN          NaN
# 1    2015-01-02   INFY     EQ  ...          NaN          NaN          NaN
# 2    2015-01-05   INFY     EQ  ...          NaN          NaN          NaN
# 3    2015-01-06   INFY     EQ  ...          NaN          NaN          NaN
# 4    2015-01-07   INFY     EQ  ...          NaN          NaN          NaN
# ..          ...    ...    ...  ...          ...          ...          ...
# 490  2016-12-26   INFY     EQ  ...  1098.750255  1099.421607  1098.283242
# 491  2016-12-27   INFY     EQ  ...  1097.751531  1098.921071  1098.281731
# 492  2016-12-28   INFY     EQ  ...  1097.019133  1098.423393  1098.332418
# 493  2016-12-29   INFY     EQ  ...  1096.281888  1097.937321  1098.445055
# 494  2016-12-30   INFY     EQ  ...  1095.522449  1097.539107  1098.594368
#
# [495 rows x 20 columns]

# %%
for i in range(5):
    n500[i+16] = roll_avg(infy['Close'], window[i])


n500.rename(columns= {16:'SMA4',
                     17:'SMA16',
                     18:'SMA28',
                     19:'SMA40',
                     20:'SMA52'}, inplace=True)

# %%
n500
# Out:
#            Date     Open     High  ...        SMA28        SMA40        SMA52
# 0    2015-01-01  6767.60  6794.25  ...          NaN          NaN          NaN
# 1    2015-01-02  6792.40  6883.05  ...          NaN          NaN          NaN
# 2    2015-01-05  6877.35  6913.25  ...          NaN          NaN          NaN
# 3    2015-01-06  6817.65  6817.65  ...          NaN          NaN          NaN
# 4    2015-01-07  6653.65  6680.50  ...          NaN          NaN          NaN
# ..          ...      ...      ...  ...          ...          ...          ...
# 490  2016-12-26  6800.20  6801.80  ...  1098.750255  1099.421607  1098.283242
# 491  2016-12-27  6730.90  6840.85  ...  1097.751531  1098.921071  1098.281731
# 492  2016-12-28  6849.45  6902.00  ...  1097.019133  1098.423393  1098.332418
# 493  2016-12-29  6846.80  6920.90  ...  1096.281888  1097.937321  1098.445055
# 494  2016-12-30  6931.85  6993.40  ...  1095.522449  1097.539107  1098.594368
#
# [495 rows x 12 columns]

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(tcs['Close'], label='Closing Price')
plt.plot(tcs['SMA4'], label='Moving average 4 weeks')
plt.plot(tcs['SMA16'], label='Moving average 16 weeks')
plt.plot(tcs['SMA28'], label='Moving average 28 weeks')
plt.plot(tcs['SMA40'], label='Moving average 40 weeks')
plt.plot(tcs['SMA52'], label='Moving average 52 weeks')
plt.legend()

# %%
# Define exponential average function
def exp_avg(close, window):
    ema = close.ewm(window).mean().shift()
    return ema

# %% [markdown]
# ## Rolling window size 10

# %%
window = 10
infy['EMA10'] = exp_avg(infy['Close'], window)
tcs['EMA10'] = exp_avg(tcs['Close'], window)
n500['EMA10'] = exp_avg(n500['Close'], window)

# %% [markdown]
# ## Rolling window size 50

# %%
window = 50
infy['EMA50'] = exp_avg(infy['Close'], window)
tcs['EMA50'] = exp_avg(tcs['Close'], window)
n500['EMA50'] = exp_avg(n500['Close'], window)

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(tcs['Close'], label='Closing Price')
plt.plot(tcs['EMA10'], label='Exp Moving average 10 days')
plt.plot(tcs['EMA50'], label='Exp Moving average 50 days')
plt.legend()

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(infy['Close'], label='Closing Price')
plt.plot(infy['EMA10'], label='Exp Moving average 10 days')
plt.plot(infy['EMA50'], label='Exp Moving average 50 days')
plt.legend()

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(n500['Close'], label='Closing Price')
plt.plot(n500['EMA10'], label='Exp Moving average 10 days')
plt.plot(n500['EMA50'], label='Exp Moving average 50 days')
plt.legend()

# %% [markdown]
# ### Relative strength index

# %%
def rsi(df, n=14):
    c = df['Close']
    delta = c.diff()
    delta = delta[1:]
    up = delta.copy()
    down = delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0
    rup = up.rolling(n).mean()
    rdown = down.abs().rolling(n).mean()
    rs = rup / rdown
    rsi = 100.0 - (100.0 / (1.0 + rs))
    return rsi

# %%
tcs['RSI'] = rsi(tcs).fillna(0)
infy['RSI'] = rsi(infy).fillna(0)
n500['RSI'] = rsi(n500).fillna(0)

# %% [markdown]
# ### Moving average convergence divergence

# %%
# Moving average convergence divergence
tcs['MACD'] = tcs['EMA10'] - tcs['EMA50']
infy['MACD'] = infy['EMA10'] - infy['EMA50']
n500['MACD'] = n500['EMA10'] - n500['EMA50']

# %%
tcs['MACD_signal'] = pd.Series(tcs.MACD.ewm(span=9, min_periods=9).mean())
infy['MACD_signal'] = pd.Series(infy.MACD.ewm(span=9, min_periods=9).mean())
n500['MACD_signal'] = pd.Series(n500.MACD.ewm(span=9, min_periods=9).mean())

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(tcs['Close'], label='Closing Price')
plt.plot(tcs['EMA10'], label='Exp Moving average 10 days')
plt.plot(tcs['EMA50'], label='Exp Moving average 50 days')
plt.plot(tcs['MACD'], label='MACD')
plt.plot(tcs['MACD_signal'], label='Signal line')
plt.legend()

# %% [markdown]
# ## Volume shock

# %% [markdown]
# ### Define a function for volume shock

# %%
# Volume shock function: future should be 10% greater than the present
def volume_shock(present, future):
    if present < (1.1 * future):
        return 1
    else:
        return 0

# %% [markdown]
# ### Volume shock for TCS

# %%
tcs['next_day_volume'] = tcs['Volume'].shift(-1)

# %%
tcs['volume_shock'] = list(map(volume_shock, tcs['Volume'],tcs['next_day_volume']))

# %%
tcs
# Out:
#            Date Symbol Series  ...  MACD_signal  next_day_volume  volume_shock
# 0    2015-01-01    TCS     EQ  ...          NaN         462870.0             1
# 1    2015-01-02    TCS     EQ  ...          NaN         877121.0             1
# 2    2015-01-05    TCS     EQ  ...          NaN        1211892.0             1
# 3    2015-01-06    TCS     EQ  ...          NaN        1318166.0             1
# 4    2015-01-07    TCS     EQ  ...          NaN         782704.0             0
# ..          ...    ...    ...  ...          ...              ...           ...
# 490  2016-12-26    TCS     EQ  ...  -106.912425         647346.0             1
# 491  2016-12-27    TCS     EQ  ...  -101.789047         675209.0             1
# 492  2016-12-28    TCS     EQ  ...   -96.461321         981758.0             1
# 493  2016-12-29    TCS     EQ  ...   -91.219563         702874.0             0
# 494  2016-12-30    TCS     EQ  ...   -85.581889              NaN             0
#
# [495 rows x 28 columns]

# %% [markdown]
# ### Volume shock for infy

# %%
infy['next_day_volume'] = infy['Volume'].shift(-1)
infy['volume_shock'] = list(map(volume_shock, infy['Volume'],infy['next_day_volume']))
infy
# Out:
#            Date Symbol Series  ...  MACD_signal  next_day_volume  volume_shock
# 0    2015-01-01   INFY     EQ  ...          NaN        1694580.0             1
# 1    2015-01-02   INFY     EQ  ...          NaN        2484256.0             1
# 2    2015-01-05   INFY     EQ  ...          NaN        2416829.0             1
# 3    2015-01-06   INFY     EQ  ...          NaN        1812479.0             0
# 4    2015-01-07   INFY     EQ  ...          NaN        3391230.0             1
# ..          ...    ...    ...  ...          ...              ...           ...
# 490  2016-12-26   INFY     EQ  ...   -43.177105        2456408.0             1
# 491  2016-12-27   INFY     EQ  ...   -41.504534        2738408.0             1
# 492  2016-12-28   INFY     EQ  ...   -39.826202        3120062.0             1
# 493  2016-12-29   INFY     EQ  ...   -38.174873        3633884.0             1
# 494  2016-12-30   INFY     EQ  ...   -36.655152              NaN             0
#
# [495 rows x 27 columns]

# %% [markdown]
# ### Volume shock for nifty 500

# %%
n500['next_day_volume'] = n500['Volume'].shift(-1)
n500['volume_shock'] = list(map(volume_shock, n500['Volume'], n500['next_day_volume']))
n500
# Out:
#            Date     Open     High  ...  MACD_signal  next_day_volume  volume_shock
# 0    2015-01-01  6767.60  6794.25  ...          NaN      617743719.0             1
# 1    2015-01-02  6792.40  6883.05  ...          NaN      614330577.0             1
# 2    2015-01-05  6877.35  6913.25  ...          NaN      716905569.0             1
# 3    2015-01-06  6817.65  6817.65  ...          NaN      723294637.0             1
# 4    2015-01-07  6653.65  6680.50  ...          NaN      654891539.0             0
# ..          ...      ...      ...  ...          ...              ...           ...
# 490  2016-12-26  6800.20  6801.80  ...  -141.827046      568808578.0             1
# 491  2016-12-27  6730.90  6840.85  ...  -149.125378      565570193.0             1
# 492  2016-12-28  6849.45  6902.00  ...  -155.937588      864984299.0             1
# 493  2016-12-29  6846.80  6920.90  ...  -161.970128      636193679.0             0
# 494  2016-12-30  6931.85  6993.40  ...  -166.278820              NaN             0
#
# [495 rows x 19 columns]

# %% [markdown]
# ## Price shock

# %% [markdown]
# ### Define a function for price shock

# %%
# Price shock function: if t and t+1 has a difference greater than 2%
def price_shock(t, t1):
    if abs((t-t1)/t) > 0.02:
        return 1
    else:
        return 0

# %% [markdown]
# ### Price shock for TCS

# %%
tcs['next_day_close'] = tcs['Close'].shift(-1)
tcs['price_shock'] = list(map(price_shock, tcs['Close'], tcs['next_day_close']))
tcs
# Out:
#            Date Symbol Series  ...  volume_shock  next_day_close  price_shock
# 0    2015-01-01    TCS     EQ  ...             1         2579.45            0
# 1    2015-01-02    TCS     EQ  ...             1         2540.25            0
# 2    2015-01-05    TCS     EQ  ...             1         2446.60            1
# 3    2015-01-06    TCS     EQ  ...             1         2417.70            0
# 4    2015-01-07    TCS     EQ  ...             0         2443.80            0
# ..          ...    ...    ...  ...           ...             ...          ...
# 490  2016-12-26    TCS     EQ  ...             1         2323.40            0
# 491  2016-12-27    TCS     EQ  ...             1         2313.40            0
# 492  2016-12-28    TCS     EQ  ...             1         2351.70            0
# 493  2016-12-29    TCS     EQ  ...             0         2365.55            0
# 494  2016-12-30    TCS     EQ  ...             0             NaN            0
#
# [495 rows x 30 columns]

# %% [markdown]
# ### Price shock for Infy

# %%
infy['next_day_close'] = infy['Close'].shift(-1)
infy['price_shock'] = list(map(price_shock, infy['Close'], infy['next_day_close']))
infy
# Out:
#            Date Symbol Series  ...  volume_shock  next_day_close  price_shock
# 0    2015-01-01   INFY     EQ  ...             1         2013.20            0
# 1    2015-01-02   INFY     EQ  ...             1         1995.90            0
# 2    2015-01-05   INFY     EQ  ...             1         1954.20            1
# 3    2015-01-06   INFY     EQ  ...             0         1963.55            0
# 4    2015-01-07   INFY     EQ  ...             1         1973.45            0
# ..          ...    ...    ...  ...           ...             ...          ...
# 490  2016-12-26   INFY     EQ  ...             1          998.95            0
# 491  2016-12-27   INFY     EQ  ...             1          998.50            0
# 492  2016-12-28   INFY     EQ  ...             1          992.35            0
# 493  2016-12-29   INFY     EQ  ...             1         1010.60            0
# 494  2016-12-30   INFY     EQ  ...             0             NaN            0
#
# [495 rows x 29 columns]

# %% [markdown]
# ### Price shock for nifty 500

# %%
n500['next_day_close'] = n500['Close'].shift(-1)
n500['price_shock'] = list(map(price_shock, n500['Close'], n500['next_day_close']))
n500
# Out:
#            Date     Open     High  ...  volume_shock  next_day_close  price_shock
# 0    2015-01-01  6767.60  6794.25  ...             1         6866.45            0
# 1    2015-01-02  6792.40  6883.05  ...             1         6857.45            0
# 2    2015-01-05  6877.35  6913.25  ...             1         6656.80            1
# 3    2015-01-06  6817.65  6817.65  ...             1         6644.95            0
# 4    2015-01-07  6653.65  6680.50  ...             0         6755.45            0
# ..          ...      ...      ...  ...           ...             ...          ...
# 490  2016-12-26  6800.20  6801.80  ...             1         6832.00            0
# 491  2016-12-27  6730.90  6840.85  ...             1         6847.40            0
# 492  2016-12-28  6849.45  6902.00  ...             1         6915.45            0
# 493  2016-12-29  6846.80  6920.90  ...             0         6982.80            0
# 494  2016-12-30  6931.85  6993.40  ...             0             NaN            0
#
# [495 rows x 21 columns]

# %% [markdown]
# ## Pricing Black Swan

# %% [markdown]
# ### Define a function for pricing black swan

# %%
# Pricing black swan function: if t and t+1 has a difference greater than 5%
def price_bs(t, t1):
    if abs((t-t1)/t) > 0.05:
        return 1
    else:
        return 0

# %% [markdown]
# ### Pricing black swan for TCS

# %%
tcs['price_bs'] = list(map(price_bs, tcs['Close'], tcs['next_day_close']))
tcs
# Out:
#            Date Symbol Series  ...  next_day_close  price_shock  price_bs
# 0    2015-01-01    TCS     EQ  ...         2579.45            0         0
# 1    2015-01-02    TCS     EQ  ...         2540.25            0         0
# 2    2015-01-05    TCS     EQ  ...         2446.60            1         0
# 3    2015-01-06    TCS     EQ  ...         2417.70            0         0
# 4    2015-01-07    TCS     EQ  ...         2443.80            0         0
# ..          ...    ...    ...  ...             ...          ...       ...
# 490  2016-12-26    TCS     EQ  ...         2323.40            0         0
# 491  2016-12-27    TCS     EQ  ...         2313.40            0         0
# 492  2016-12-28    TCS     EQ  ...         2351.70            0         0
# 493  2016-12-29    TCS     EQ  ...         2365.55            0         0
# 494  2016-12-30    TCS     EQ  ...             NaN            0         0
#
# [495 rows x 31 columns]

# %% [markdown]
# ### Pricing black swan for Infy

# %%
infy['price_bs'] = list(map(price_bs, infy['Close'], infy['next_day_close']))
infy
# Out:
#            Date Symbol Series  ...  next_day_close  price_shock  price_bs
# 0    2015-01-01   INFY     EQ  ...         2013.20            0         0
# 1    2015-01-02   INFY     EQ  ...         1995.90            0         0
# 2    2015-01-05   INFY     EQ  ...         1954.20            1         0
# 3    2015-01-06   INFY     EQ  ...         1963.55            0         0
# 4    2015-01-07   INFY     EQ  ...         1973.45            0         0
# ..          ...    ...    ...  ...             ...          ...       ...
# 490  2016-12-26   INFY     EQ  ...          998.95            0         0
# 491  2016-12-27   INFY     EQ  ...          998.50            0         0
# 492  2016-12-28   INFY     EQ  ...          992.35            0         0
# 493  2016-12-29   INFY     EQ  ...         1010.60            0         0
# 494  2016-12-30   INFY     EQ  ...             NaN            0         0
#
# [495 rows x 30 columns]

# %% [markdown]
# ### Pricing black swan for nifty 500

# %%
n500['price_bs'] = list(map(price_bs, n500['Close'], n500['next_day_close']))
n500
# Out:
#            Date     Open     High  ...  next_day_close  price_shock  price_bs
# 0    2015-01-01  6767.60  6794.25  ...         6866.45            0         0
# 1    2015-01-02  6792.40  6883.05  ...         6857.45            0         0
# 2    2015-01-05  6877.35  6913.25  ...         6656.80            1         0
# 3    2015-01-06  6817.65  6817.65  ...         6644.95            0         0
# 4    2015-01-07  6653.65  6680.50  ...         6755.45            0         0
# ..          ...      ...      ...  ...             ...          ...       ...
# 490  2016-12-26  6800.20  6801.80  ...         6832.00            0         0
# 491  2016-12-27  6730.90  6840.85  ...         6847.40            0         0
# 492  2016-12-28  6849.45  6902.00  ...         6915.45            0         0
# 493  2016-12-29  6846.80  6920.90  ...         6982.80            0         0
# 494  2016-12-30  6931.85  6993.40  ...             NaN            0         0
#
# [495 rows x 22 columns]

# %% [markdown]
# ### Pricing shock without volume shock

# %%
tcs_new = tcs.loc[(tcs['volume_shock']==0) & (tcs['price_shock']==1)]
tcs_new
# Out:
#            Date Symbol Series  ...  next_day_close  price_shock  price_bs
# 64   2015-04-07    TCS     EQ  ...         2641.40            1         0
# 186  2015-09-30    TCS     EQ  ...         2644.60            1         0
# 266  2016-01-28    TCS     EQ  ...         2391.30            1         0
# 272  2016-02-05    TCS     EQ  ...         2362.95            1         0
# 308  2016-03-31    TCS     EQ  ...         2453.90            1         0
# 318  2016-04-18    TCS     EQ  ...         2450.35            1         0
# 348  2016-05-31    TCS     EQ  ...         2633.55            1         0
# 370  2016-06-30    TCS     EQ  ...         2500.85            1         0
# 401  2016-08-16    TCS     EQ  ...         2624.55            1         0
# 405  2016-08-22    TCS     EQ  ...         2601.05            1         0
# 422  2016-09-16    TCS     EQ  ...         2411.45            1         0
# 461  2016-11-15    TCS     EQ  ...         2189.60            1         0
# 462  2016-11-16    TCS     EQ  ...         2137.20            1         0
#
# [13 rows x 31 columns]

# %%
infy_new = infy.loc[(infy['volume_shock']==0) & (infy['price_shock']==1)]
infy_new
# Out:
#            Date Symbol Series  ...  next_day_close  price_shock  price_bs
# 6    2015-01-09   INFY     EQ  ...         2115.95            1         0
# 58   2015-03-26   INFY     EQ  ...         2202.15            1         0
# 61   2015-03-31   INFY     EQ  ...         2173.95            1         0
# 115  2015-06-19   INFY     EQ  ...         1023.85            1         0
# 131  2015-07-13   INFY     EQ  ...          971.25            1         0
# 142  2015-07-28   INFY     EQ  ...         1085.40            1         0
# 147  2015-08-04   INFY     EQ  ...         1086.35            1         0
# 164  2015-08-27   INFY     EQ  ...         1111.05            1         0
# 169  2015-09-03   INFY     EQ  ...         1073.95            1         0
# 183  2015-09-24   INFY     EQ  ...         1105.55            1         0
# 193  2015-10-12   INFY     EQ  ...         1099.40            1         0
# 212  2015-11-09   INFY     EQ  ...         1103.85            1         0
# 218  2015-11-18   INFY     EQ  ...         1047.80            1         0
# 275  2016-02-10   INFY     EQ  ...         1078.65            1         0
# 288  2016-02-29   INFY     EQ  ...         1125.45            1         0
# 309  2016-04-01   INFY     EQ  ...         1243.70            1         0
# 361  2016-06-17   INFY     EQ  ...         1208.75            1         0
# 366  2016-06-24   INFY     EQ  ...         1166.20            1         0
# 405  2016-08-22   INFY     EQ  ...         1039.65            1         0
# 407  2016-08-24   INFY     EQ  ...         1036.15            1         0
# 468  2016-11-24   INFY     EQ  ...          977.50            1         1
#
# [21 rows x 30 columns]

# %%
n500_new = n500.loc[(n500['volume_shock']==0) & (n500['price_shock']==1)]
n500_new
# Out:
#            Date     Open     High  ...  next_day_close  price_shock  price_bs
# 262  2016-01-21  6171.20  6196.30  ...         6216.70            1         0
# 277  2016-02-12  5878.80  5878.80  ...         5999.05            1         0
# 288  2016-02-29  5869.85  5897.95  ...         6020.05            1         0
# 418  2016-09-09  7634.50  7634.50  ...         7420.50            1         0
#
# [4 rows x 22 columns]

# %% [markdown]
# # Part 2 : Data Visualization

# %% [markdown]
# pip install altair

# %% [markdown]
# pip install altair vega_datasets

# %%
pip install altair vega_datasets
# Out:
# Requirement already satisfied: altair in /usr/local/lib/python3.6/dist-packages (4.1.0)
# Requirement already satisfied: vega_datasets in /usr/local/lib/python3.6/dist-packages (0.8.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from altair) (2.11.2)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.6/dist-packages (from altair) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from altair) (1.18.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from altair) (0.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from altair) (2.6.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.6/dist-packages (from altair) (0.11.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18->altair) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18->altair) (1.15.0)

# %%
import altair as alt

# %% [markdown]
# pip install vega

# %%
line1 = alt.Chart(infy).mark_line().encode(x='Date', y='Close')
line2 = alt.Chart(infy).mark_area(
    line={'color':'black'},
    color=alt.Gradient(
        gradient='linear',
        stops=[alt.GradientStop(color='white', offset=0),
               alt.GradientStop(color='blue', offset=1)],
        x1=1,
        x2=1,
        y1=1,
        y2=0)
    ).encode(x='Date', y='SMA52')

line3 = alt.Chart(infy_new).mark_point(color='green').encode(
    x='Date',
    y='Close'
)
line1+line2+line3
# Out:
# alt.LayerChart(...)

# %%
line = alt.Chart(infy).mark_line().encode(
    x='Date',
    y='Close', 
    color=alt.condition(
        alt.datum.volume_shock < 0,
        alt.value("steelblue"),  # The positive color
        alt.value("orange"))  # The negative color
).properties(width=1200)
line
# Out:
# alt.Chart(...)

# %%
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
dt = infy[['Close']]
plot_acf(dt, lags=50)
plt.show()

# %%
plot_pacf(dt, lags=50)
plt.show()

# %% [markdown]
# # Part 3

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### TCS

# %%
tcs_new = tcs

# %%
# Predict for next day price
tcs_new['Close'] = tcs_new['Close'].shift(-1)

# %%
tcs_new = tcs_new[:-1]

# %%
tcs_new = tcs_new.drop(['Date','Open','High','Low','Last','Prev Close','VWAP','Volume','Turnover','Trades',
                  'Deliverable Volume','%Deliverble','SMA','Symbol','Series','next_day_volume','next_day_close',
                 'SMA28','SMA40','SMA52'],1)

# %%
tcs_new = tcs_new.dropna()

# %%
tcs_x = tcs_new.drop(['Close'],1)
tcs_y = tcs_new['Close'].copy()

# %%
tcs_x.reset_index()
tcs_y.reset_index()
# Out:
#      index    Close
# 0      112  2513.80
# 1      113  2530.05
# 2      114  2549.55
# 3      115  2591.50
# 4      116  2574.60
# ..     ...      ...
# 377    489  2293.10
# 378    490  2323.40
# 379    491  2313.40
# 380    492  2351.70
# 381    493  2365.55
#
# [382 rows x 2 columns]

# %%
x_train_tcs , x_test_tcs, y_train_tcs, y_test_tcs = train_test_split(tcs_x , tcs_y, test_size=0.15)

# %%
x_train_tcs , x_valid_tcs, y_train_tcs, y_valid_tcs = train_test_split(x_train_tcs , y_train_tcs, test_size=0.177)

# %%
print('x train shape : ', x_train_tcs.shape)
print('y train shape : ', y_train_tcs.shape)

print('x valid shape :', x_valid_tcs.shape)
print('y valid shape :', y_valid_tcs.shape)

print('x test shape :', x_test_tcs.shape)
print('y test shape :', y_test_tcs.shape)
# Out:
# x train shape :  (266, 10)
# y train shape :  (266,)
# x valid shape : (58, 10)
# y valid shape : (58,)
# x test shape : (58, 10)
# y test shape : (58,)

# %% [markdown]
# ### Gridsearch

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.model_selection import cross_val_score, KFold
import math

# %%
param = {
    'n_estimators': [100, 200, 300, 400, 500, 700, 1000, 1200],
    'learning_rate': [0.001, 0.005, 0.01, 0.05],
    'max_depth': [4, 8, 10, 12, 15, 20],
    'gamma': [0.001, 0.005, 0.01, 0.05],
    'random_state': [10]
    }

# %%
eval_set = [x_train_tcs, y_train_tcs]
model_wo_grid = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
model_wo_grid.fit(x_train_tcs, y_train_tcs, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1,
#              eval_set=[            SMA4        SMA16        EMA10  ...  volume_shock  price_shock  price_bs
# 342  2504.948214  2396.599107  2517.027530  ...             0            0         0
# 399  2550.341071  2507.959821  2603.871005  ...             1            0         0
# 231  2423.414286  2533.839732  2391.181392  ...             1            0         0
# 238  2387.148214  2521.058482  2385.238307  ...             1            0         0
# 178  2600.067857  2559.29...
# 172    2549.75
# 187    2711.65
# Name: Close, Length: 266, dtype: float64],
#              gamma=0, importance_type='gain', learning_rate=0.1,
#              max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#              n_estimators=100, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=1, verbose=False, verbosity=1)

# %%
y_pred_tcs = model_wo_grid.predict(x_valid_tcs)
mse_wo_grid = mean_squared_error(y_valid_tcs, y_pred_tcs)
print('Mean squared error without grid search',mse_wo_grid)
# Out:
# Mean squared error without grid search 1779.7677018799038

# %%
eval_set = [(x_train_tcs, y_train_tcs) , (x_valid_tcs, y_valid_tcs)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
grid = GridSearchCV(model, param)
grid.fit(x_train_tcs, y_train_tcs)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1,
#                                     eval_set=[(            SMA4        SMA16        EMA10  ...  volume_shock  price_shock  price_bs
# 342  2504.948214  2396.599107  2517.027530  ...             0            0         0
# 399  2550.341071  2507.959821  2603.871005  ...             1            0         0
# 231  2423.414286  2533.839732  2391.181392  ...             1            0         0
# 238  2387.148214  2...
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbose=False, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'gamma': [0.001, 0.005, 0.01, 0.05],
#                          'learning_rate': [0.001, 0.005, 0.01, 0.05],
#                          'max_depth': [4, 8, 10, 12, 15, 20],
#                          'n_estimators': [100, 200, 300, 400, 500, 700, 1000,
#                                           1200],
#                          'random_state': [10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print('Best parameters : ',grid.best_params_)
print('Score :',grid.best_score_)
# Out:
# Best parameters :  {'gamma': 0.005, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 700, 'random_state': 10}
# Score : 0.910222052210781

# %%
model = xgb.XGBRegressor(**grid.best_params_, objective='reg:squarederror')
model.fit(x_train_tcs, y_train_tcs, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.005,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=8, min_child_weight=1, missing=None, n_estimators=700,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=10, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=1, verbosity=1)

# %%
plot_importance(model)

# %%
y_pred_tcs = model.predict(x_valid_tcs)

# %%
mse = mean_squared_error(y_valid_tcs, y_pred_tcs)
print('Mean squared error :',mse)
print('Root mean squared error : ', math.sqrt(mse))
# Out:
# Mean squared error : 937.3824732145766
# Root mean squared error :  30.616702520267864

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
ax = range(len(y_valid_tcs))
plt.plot(ax, y_valid_tcs, label="original")
plt.plot(ax, y_pred_tcs, label="predicted")
plt.title("Validation Set")
plt.legend()
plt.show()

# %% [markdown]
# ### K-Fold

# %%
#Cross validataion 
scores = cross_val_score(model, x_train_tcs, y_train_tcs, cv=5)
print("Mean cross-validation score: %.2f" % scores.mean())
# Out:
# Mean cross-validation score: 0.91

# %%
# K-Fold
kfold = KFold(n_splits=3, shuffle=True)
kf_cv_scores = cross_val_score(model, x_train_tcs, y_train_tcs, cv=kfold )
print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
# Out:
# K-fold CV average score: 0.90

# %%
y_pred_tcs = model.predict(x_test_tcs)
mse = mean_squared_error(y_test_tcs, y_pred_tcs)
print('Mean squared error :',mse)
print('Root mean squared error : ', math.sqrt(mse))
# Out:
# Mean squared error : 1378.2258240983815
# Root mean squared error :  37.124463957051034

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
ax = range(len(y_test_tcs))
plt.plot(ax, y_test_tcs, label="original")
plt.plot(ax, y_pred_tcs, label="predicted")
plt.title("Test Set")
plt.legend()
plt.show()

# %% [markdown]
# ### OLS

# %%
import statsmodels.api as sm

# %%
x = tcs_new['RSI'].tolist() 
y = tcs_new['Close'].tolist()

# %%
x = sm.add_constant(x)
result = sm.OLS(y, x).fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     71.19
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           6.88e-16
# Time:                        15:16:12   Log-Likelihood:                -2379.2
# No. Observations:                 382   AIC:                             4762.
# Df Residuals:                     380   BIC:                             4770.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2286.6464     20.872    109.556      0.000    2245.607    2327.686
# x1             3.3948      0.402      8.437      0.000       2.604       4.186
# ==============================================================================
# Omnibus:                       32.654   Durbin-Watson:                   0.110
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.645
# Skew:                          -0.436   Prob(JB):                     3.29e-05
# Kurtosis:                       2.268   Cond. No.                         172.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = tcs_new['RSI'].tolist() 
y = tcs_new['Close'].tolist()
x = sm.add_constant(x)
result = sm.OLS(y, x).fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     71.19
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           6.88e-16
# Time:                        15:16:12   Log-Likelihood:                -2379.2
# No. Observations:                 382   AIC:                             4762.
# Df Residuals:                     380   BIC:                             4770.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2286.6464     20.872    109.556      0.000    2245.607    2327.686
# x1             3.3948      0.402      8.437      0.000       2.604       4.186
# ==============================================================================
# Omnibus:                       32.654   Durbin-Watson:                   0.110
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.645
# Skew:                          -0.436   Prob(JB):                     3.29e-05
# Kurtosis:                       2.268   Cond. No.                         172.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Infy

# %%
infy_new = infy
# Predict for next day price
infy_new['Close'] = infy_new['Close'].shift(-1)
infy_new = infy_new.drop(['Date','Open','High','Low','Last','Prev Close','VWAP','Volume','Turnover','Trades',
                  'Deliverable Volume','%Deliverble','Symbol','Series','next_day_volume','next_day_close',
                 'SMA28','SMA40','SMA52'],1)

infy_new = infy_new.dropna()

infy_x = infy_new.drop(['Close'],1)
infy_y = infy_new['Close'].copy()

infy_x.reset_index()
infy_y.reset_index()
# Out:
#      index    Close
# 0      112   995.70
# 1      113  1001.95
# 2      114   995.35
# 3      115  1023.85
# 4      116  1000.40
# ..     ...      ...
# 377    489   982.75
# 378    490   998.95
# 379    491   998.50
# 380    492   992.35
# 381    493  1010.60
#
# [382 rows x 2 columns]

# %%
x_train_infy , x_test_infy, y_train_infy, y_test_infy = train_test_split(infy_x , infy_y, test_size=0.15)

# %%
x_train_infy , x_valid_infy, y_train_infy, y_valid_infy = train_test_split(x_train_infy , y_train_infy, test_size=0.177)

# %%
print('x train shape : ', x_train_infy.shape)
print('y train shape : ', y_train_infy.shape)

print('x valid shape :', x_valid_infy.shape)
print('y valid shape :', y_valid_infy.shape)

print('x test shape :', x_test_infy.shape)
print('y test shape :', y_test_infy.shape)
# Out:
# x train shape :  (266, 10)
# y train shape :  (266,)
# x valid shape : (58, 10)
# y valid shape : (58,)
# x test shape : (58, 10)
# y test shape : (58,)

# %%
eval_set = [x_train_infy, y_train_infy]
model_wo_grid = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
model_wo_grid.fit(x_train_infy, y_train_infy, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1,
#              eval_set=[            SMA4        SMA16        EMA10  ...  volume_shock  price_shock  price_bs
# 226  1105.228571  1081.884375  1084.167754  ...             1            0         0
# 154  1042.892857  1686.605804  1087.462194  ...             0            0         0
# 152  1033.062500  1707.450446  1079.030250  ...             1            1         0
# 438  1041.426786  1125.161607  1039.947798  ...             1            1         0
# 131  1278.457143  1930.16...
# 168    1099.35
# 236    1095.85
# Name: Close, Length: 266, dtype: float64],
#              gamma=0, importance_type='gain', learning_rate=0.1,
#              max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#              n_estimators=100, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=1, verbose=False, verbosity=1)

# %%
y_pred_infy = model_wo_grid.predict(x_valid_infy)
mse_wo_grid = mean_squared_error(y_valid_infy, y_pred_infy)
print('Mean squared error without grid search',mse_wo_grid)
# Out:
# Mean squared error without grid search 329.00138427213665

# %%
eval_set = [(x_train_infy, y_train_infy) , (x_valid_infy, y_valid_infy)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
grid = GridSearchCV(model, param)
grid.fit(x_train_infy, y_train_infy)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1,
#                                     eval_set=[(            SMA4        SMA16        EMA10  ...  volume_shock  price_shock  price_bs
# 226  1105.228571  1081.884375  1084.167754  ...             1            0         0
# 154  1042.892857  1686.605804  1087.462194  ...             0            0         0
# 152  1033.062500  1707.450446  1079.030250  ...             1            1         0
# 438  1041.426786  1...
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbose=False, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'gamma': [0.001, 0.005, 0.01, 0.05],
#                          'learning_rate': [0.001, 0.005, 0.01, 0.05],
#                          'max_depth': [4, 8, 10, 12, 15, 20],
#                          'n_estimators': [100, 200, 300, 400, 500, 700, 1000,
#                                           1200],
#                          'random_state': [10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print('Best parameters : ',grid.best_params_)
print('Score :',grid.best_score_)
# Out:
# Best parameters :  {'gamma': 0.01, 'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 700, 'random_state': 10}
# Score : 0.9357995289724867

# %%
model = xgb.XGBRegressor(**grid.best_params_, objective='reg:squarederror')
model.fit(x_train_infy, y_train_infy, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.01,
#              importance_type='gain', learning_rate=0.05, max_delta_step=0,
#              max_depth=8, min_child_weight=1, missing=None, n_estimators=700,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=10, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=1, verbosity=1)

# %%
plot_importance(model)

# %%
y_pred_infy = model.predict(x_valid_infy)
mse = mean_squared_error(y_valid_infy, y_pred_infy)
print('Mean squared error :',mse)
print('Root mean squared error : ', math.sqrt(mse))
# Out:
# Mean squared error : 293.2231932512572
# Root mean squared error :  17.123761072009188

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
ax = range(len(y_valid_infy))
plt.plot(ax, y_valid_infy, label="original")
plt.plot(ax, y_pred_infy, label="predicted")
plt.title("Validation Set")
plt.legend()
plt.show()

# %% [markdown]
# ### K-Fold

# %%
# K-Fold
kfold = KFold(n_splits=3, shuffle=True)
kf_cv_scores = cross_val_score(model, x_train_infy, y_train_infy, cv=kfold )
print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
# Out:
# K-fold CV average score: 0.93

# %% [markdown]
# ### Test set

# %%
y_pred_infy = model.predict(x_test_infy)
mse = mean_squared_error(y_test_infy, y_pred_infy)
print('Mean squared error :',mse)
print('Root mean squared error : ', math.sqrt(mse))
# Out:
# Mean squared error : 320.0965095531424
# Root mean squared error :  17.891241140657137

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
ax = range(len(y_test_infy))
plt.plot(ax, y_test_infy, label="original")
plt.plot(ax, y_pred_infy, label="predicted")
plt.title("Test Set")
plt.legend()
plt.show()

# %% [markdown]
# ### OLS

# %%
x = infy_new['RSI'].tolist() 
y = infy_new['Close'].tolist()
x = sm.add_constant(x)
result = sm.OLS(y, x).fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.173
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     79.27
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           2.26e-17
# Time:                        15:29:55   Log-Likelihood:                -2179.4
# No. Observations:                 382   AIC:                             4363.
# Df Residuals:                     380   BIC:                             4371.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        996.0861     11.559     86.174      0.000     973.359    1018.814
# x1             2.0198      0.227      8.904      0.000       1.574       2.466
# ==============================================================================
# Omnibus:                        5.386   Durbin-Watson:                   0.093
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                3.629
# Skew:                          -0.058   Prob(JB):                        0.163
# Kurtosis:                       2.537   Cond. No.                         158.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = infy_new['MACD'].tolist() 
y = infy_new['Close'].tolist()
x = sm.add_constant(x)
result = sm.OLS(y, x).fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.146
# Method:                 Least Squares   F-statistic:                     66.23
# Date:                Thu, 29 Oct 2020   Prob (F-statistic):           5.78e-15
# Time:                        15:29:56   Log-Likelihood:                -2184.9
# No. Observations:                 382   AIC:                             4374.
# Df Residuals:                     380   BIC:                             4382.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1114.9031      4.608    241.963      0.000    1105.843    1123.963
# x1             0.2040      0.025      8.138      0.000       0.155       0.253
# ==============================================================================
# Omnibus:                       16.958   Durbin-Watson:                   0.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               12.053
# Skew:                          -0.320   Prob(JB):                      0.00241
# Kurtosis:                       2.410   Cond. No.                         224.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### NIFTY 500

# %%
n500_new = n500
# Predict for next day price
n500_new['Close'] = n500_new['Close'].shift(-1)
n500_new = n500_new.drop(['Date','Open','High','Low','Volume','Turnover','next_day_volume','next_day_close',
                         'SMA28','SMA40','SMA52'],1)

n500_new = n500_new.dropna()

n500_x = n500_new.drop(['Close'],1)
n500_y = n500_new['Close'].copy()

n500_x.reset_index()
n500_y.reset_index()
n500_x
# Out:
#             SMA4        SMA16        EMA10  ...  volume_shock  price_shock  price_bs
# 112  1963.741071  2116.502679  6740.283517  ...             1            0         0
# 113  1930.003571  2107.796875  6729.984799  ...             1            0         0
# 114  1895.637500  2098.712054  6725.513368  ...             1            0         0
# 115  1860.219643  2089.837500  6727.453096  ...             1            0         0
# 116  1826.228571  2081.276339  6732.693806  ...             0            0         0
# ..           ...          ...          ...  ...           ...          ...       ...
# 489   966.857143  1024.784821  6987.488290  ...             0            0         0
# 490   969.175000  1023.105357  6971.798445  ...             1            0         0
# 491   970.669643  1021.220982  6949.312223  ...             1            0         0
# 492   973.139286  1019.637946  6938.647475  ...             1            0         0
# 493   975.942857  1018.976786  6930.352250  ...             0            0         0
#
# [382 rows x 10 columns]

# %%
x_train_n500 , x_test_n500, y_train_n500, y_test_n500 = train_test_split(n500_x , n500_y, test_size=0.15)

# %%
x_train_n500 , x_valid_n500, y_train_n500, y_valid_n500 = train_test_split(x_train_n500 , y_train_n500,
                                                                           test_size=0.177)

# %%
print('x train shape : ', x_train_n500.shape)
print('y train shape : ', y_train_infy.shape)

print('x valid shape :', x_valid_infy.shape)
print('y valid shape :', y_valid_infy.shape)

print('x test shape :', x_test_infy.shape)
print('y test shape :', y_test_infy.shape)
# Out:
# x train shape :  (266, 10)
# y train shape :  (266,)
# x valid shape : (58, 10)
# y valid shape : (58,)
# x test shape : (58, 10)
# y test shape : (58,)

# %%
eval_set = [x_train_n500, y_train_n500]
model_wo_grid = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
model_wo_grid.fit(x_train_n500, y_train_n500, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1,
#              eval_set=[            SMA4        SMA16        EMA10  ...  volume_shock  price_shock  price_bs
# 313  1170.057143  1118.906696  6324.806229  ...             0            0         0
# 415  1056.094643  1159.139286  7374.157143  ...             1            0         0
# 411  1062.189286  1164.111161  7323.084413  ...             1            0         0
# 246  1068.364286  1098.203571  6610.798574  ...             1            0         0
# 163  1098.614286  1598.71...
# 466    6882.65
# 134    7148.05
# Name: Close, Length: 266, dtype: float64],
#              gamma=0, importance_type='gain', learning_rate=0.1,
#              max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#              n_estimators=100, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=1, verbose=False, verbosity=1)

# %%
y_pred_n500 = model_wo_grid.predict(x_valid_n500)
mse_wo_grid = mean_squared_error(y_valid_n500, y_pred_n500)
print('Mean squared error without grid search',mse_wo_grid)
# Out:
# Mean squared error without grid search 7322.105586410886

# %%
eval_set = [(x_train_n500, y_train_n500) , (x_valid_n500, y_valid_n500)]
model = xgb.XGBRegressor(eval_set=eval_set, objective='reg:squarederror', verbose=False)
grid = GridSearchCV(model, param)
grid.fit(x_train_n500, y_train_n500)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1,
#                                     eval_set=[(            SMA4        SMA16        EMA10  ...  volume_shock  price_shock  price_bs
# 313  1170.057143  1118.906696  6324.806229  ...             0            0         0
# 415  1056.094643  1159.139286  7374.157143  ...             1            0         0
# 411  1062.189286  1164.111161  7323.084413  ...             1            0         0
# 246  1068.364286  1...
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbose=False, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'gamma': [0.001, 0.005, 0.01, 0.05],
#                          'learning_rate': [0.001, 0.005, 0.01, 0.05],
#                          'max_depth': [4, 8, 10, 12, 15, 20],
#                          'n_estimators': [100, 200, 300, 400, 500, 700, 1000,
#                                           1200],
#                          'random_state': [10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print('Best parameters : ',grid.best_params_)
print('Score :',grid.best_score_)
# Out:
# Best parameters :  {'gamma': 0.05, 'learning_rate': 0.01, 'max_depth': 12, 'n_estimators': 1000, 'random_state': 10}
# Score : 0.9635079490302166

# %%
model = xgb.XGBRegressor(**grid.best_params_, objective='reg:squarederror')
model.fit(x_train_n500, y_train_n500, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.05,
#              importance_type='gain', learning_rate=0.01, max_delta_step=0,
#              max_depth=12, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=10, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=1, verbosity=1)

# %%
plot_importance(model)

# %%
y_pred_n500 = model.predict(x_valid_n500)
mse = mean_squared_error(y_valid_n500, y_pred_n500)
print('Mean squared error :',mse)
print('Root mean squared error : ', math.sqrt(mse))
# Out:
# Mean squared error : 6976.639915863895
# Root mean squared error :  83.52628278490486

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
ax = range(len(y_valid_n500))
plt.plot(ax, y_valid_n500, label="original")
plt.plot(ax, y_pred_n500, label="predicted")
plt.title("Validation Set")
plt.legend()
plt.show()

# %% [markdown]
# ### K-Fold

# %%
# K-Fold
kfold = KFold(n_splits=3, shuffle=True)
kf_cv_scores = cross_val_score(model, x_train_n500, y_train_n500, cv=kfold )
print("K-fold CV average score: %.2f" % kf_cv_scores.mean())
# Out:
# K-fold CV average score: 0.95

# %%
y_pred_n500 = model.predict(x_test_n500)
mse = mean_squared_error(y_test_n500, y_pred_n500)
print('Mean squared error :',mse)
print('Root mean squared error : ', math.sqrt(mse))
# Out:
# Mean squared error : 4701.52276718879
# Root mean squared error :  68.5676510257482

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
ax = range(len(y_test_n500))
plt.plot(ax, y_test_n500, label="original")
plt.plot(ax, y_pred_n500, label="predicted")
plt.title("Test Set")
plt.legend()
plt.show()

# %%
# End
